# %% [markdown]
# # SSMESR

# %%
import httpx


def fetch_data(url: str):
    with httpx.Client() as client:
        try:
            response = client.get(url)
            response.raise_for_status()
            return response.json()
        except Exception as error:
            print(f"Error while fetching {url=}: {error}")


def get_data():
    base_url = "https://zenodo.org/api/records?communities=ssm-esr&size=25&page=1"
    data = fetch_data(base_url)
    return data

# %%
data = get_data()

# %%
data.keys()
# Out:
# dict_keys(['hits', 'aggregations', 'links'])

# %%
data.get("hits").keys()
# Out:
# dict_keys(['hits', 'total'])

# %%
example = data.get("hits", {}).get("hits")[2]

# %%
example
# Out:
# {'created': '2026-03-24T09:32:59.797412+00:00',
#  'modified': '2026-04-21T16:27:50.162756+00:00',
#  'id': 18984755,
#  'conceptrecid': '18984754',
#  'doi': '10.5281/zenodo.18984755',
#  'conceptdoi': '10.5281/zenodo.18984754',
#  'doi_url': 'https://doi.org/10.5281/zenodo.18984755',
#  'metadata': {'title': "Le financement de la recherche et de l'enseignement supérieur par les collectivités territoriales entre 2023 et 2025",
#   'doi': '10.5281/zenodo.18984755',
#   'publication_date': '2026-03-24',
# ...

# %%
data.get("aggregations")
# Out:
# {'access_status': {'buckets': [{'key': 'open',
#     'doc_count': 911,
#     'label': 'Open',
#     'is_selected': False}],
#   'label': 'Access status'},
#  'resource_type': {'buckets': [{'key': 'publication',
#     'doc_count': 911,
#     'label': 'Publication',
#     'is_selected': False,
#     'inner': {'buckets': [{'key': 'publication-article',
#        'doc_count': 842,
#        'label': 'Journal article',
#        'is_selected': False},
#       {'key': 'publication-book',
#        'doc_count': 69,
#        'label': 'Book',
#        'is_selected': False}]}}],
#   'label': 'Resource types'},
#  'subject': {'buckets': [{'key': 'Emploi scientifique',
#     'doc_count': 1,
#     'label': 'Emploi scientifique',
#     'is_selected': False}],
#   'label': 'Subjects'},
#  'file_type': {'buckets': [{'key': 'pdf',
#     'doc_count': 893,
#     'label': 'PDF',
#     'is_selected': False},
#    {'key': 'xlsx', 'doc_count': 115, 'label': 'XLSX', 'is_selected': False},
# ...

# %%
data.get("links")
# Out:
# {'self': 'https://zenodo.org/api/records?communities=ssm-esr&page=1&size=25&sort=newest',
#  'next': 'https://zenodo.org/api/records?communities=ssm-esr&page=2&size=25&sort=newest'}

# %%
data.get("hits").get("hits")[0]
# Out:
# {'created': '2026-03-27T09:45:30.042413+00:00',
#  'modified': '2026-03-27T09:45:30.647460+00:00',
#  'id': 18984935,
#  'conceptrecid': '18984934',
#  'doi': '10.5281/zenodo.18984935',
#  'conceptdoi': '10.5281/zenodo.18984934',
#  'doi_url': 'https://doi.org/10.5281/zenodo.18984935',
#  'metadata': {'title': "L'activité de R&D selon les catégories d'entreprises en 2023 – résultats détaillés pour 2023",
#   'doi': '10.5281/zenodo.18984935',
#   'publication_date': '2026-03-26',
# ...

# %% [markdown]
# df analysis

# %%
import pandas as pd

df = pd.read_json("./data/records.jsonl", lines=True)
df
# Out:
#            created                modified        id  conceptrecid  \
# 0    1762334680954 2026-02-16 08:14:00.800  17530971      17530970
# 1    1762339497525 2026-02-16 08:15:31.286  17531403      17531402
# 2    1762339741994 2026-02-16 08:15:35.338  17531853      17531852
# 3    1763048231588 2026-02-16 08:17:20.483  17601868      17601867
# 4    1763048364823 2026-02-16 08:17:25.241  17601893      17601892
# ..             ...                     ...       ...           ...
# 906  1771248297863 2026-03-10 16:24:28.662  18660901      18660900
# 907  1773159984021 2026-03-10 16:32:37.377  18836560      18836559
# 908  1772092816575 2026-03-12 15:34:42.939  18758226      18758225
# 909  1774344779797 2026-03-24 09:33:00.302  18984755      18984754
# 910  1774604730042 2026-03-27 09:45:30.647  18984935      18984934
#
#                          doi               conceptdoi  \
# 0    10.5281/zenodo.17530971  10.5281/zenodo.17530970
# ...

# %%
resource_types = pd.json_normalize(df["metadata"])
resource_types
# Out:
#                                                  title  \
# 0    L'état de l'Enseignement supérieur et de la Re...
# 1    Les étudiants dans les écoles de management re...
# 2    Coût de l'Éducation en 2009 Évaluation proviso...
# 3    Les étudiants inscrits dans les universités pu...
# 4    Le taux d'emploi salarié en France des diplômé...
# ..                                                 ...
# 906  Enseignement supérieur et recherche : vers l'é...
# 907  Vers l'égalité femmes-hommes ? Chiffres clés 2026
# 908   Le Baromètre français de la Science Ouverte 2025
# 909  Le financement de la recherche et de l'enseign...
# 910  L'activité de R&D selon les catégories d'entre...
#
#                          doi publication_date  \
# 0    10.5281/zenodo.17530971       2014-04-01
# 1    10.5281/zenodo.17531403       2010-12-01
# 2    10.5281/zenodo.17531853       2011-12-01
# 3    10.5281/zenodo.17601868       2010-10-01
# 4    10.5281/zenodo.17601893       2024-12-19
# ...

# %%
resource_types["resource_type.subtype"].value_counts()
# Out:
# resource_type.subtype
# article    842
# book        69
# Name: count, dtype: int64

# %%
df_exploded = df.explode(["files"], ignore_index=True)
df_norm = pd.json_normalize(df_exploded["files"])
df_files = pd.concat([df_exploded.drop(columns=["files"]).reset_index(drop=True), df_norm.reset_index(drop=True)], axis=1)
df_files
# Out:
#             created                modified        id  conceptrecid  \
# 0     1762334680954 2026-02-16 08:14:00.800  17530971      17530970
# 1     1762339497525 2026-02-16 08:15:31.286  17531403      17531402
# 2     1762339741994 2026-02-16 08:15:35.338  17531853      17531852
# 3     1763048231588 2026-02-16 08:17:20.483  17601868      17601867
# 4     1763048364823 2026-02-16 08:17:25.241  17601893      17601892
# ...             ...                     ...       ...           ...
# 1075  1772092816575 2026-03-12 15:34:42.939  18758226      18758225
# 1076  1774344779797 2026-03-24 09:33:00.302  18984755      18984754
# 1077  1774344779797 2026-03-24 09:33:00.302  18984755      18984754
# 1078  1774604730042 2026-03-27 09:45:30.647  18984935      18984934
# 1079  1774604730042 2026-03-27 09:45:30.647  18984935      18984934
#
#                           doi               conceptdoi  \
# 0     10.5281/zenodo.17530971  10.5281/zenodo.17530970
# ...

# %%
df.head(2).to_dict()
# Out:
# {'created': {0: 1762334680954, 1: 1762339497525},
#  'modified': {0: Timestamp('2026-02-16 08:14:00.800000'),
#   1: Timestamp('2026-02-16 08:15:31.286000')},
#  'id': {0: 17530971, 1: 17531403},
#  'conceptrecid': {0: 17530970, 1: 17531402},
#  'doi': {0: '10.5281/zenodo.17530971', 1: '10.5281/zenodo.17531403'},
#  'conceptdoi': {0: '10.5281/zenodo.17530970', 1: '10.5281/zenodo.17531402'},
#  'doi_url': {0: 'https://doi.org/10.5281/zenodo.17530971',
#   1: 'https://doi.org/10.5281/zenodo.17531403'},
#  'metadata': {0: {'title': "L'état de l'Enseignement supérieur et de la Recherche en France n°7",
#    'doi': '10.5281/zenodo.17530971',
#    'publication_date': '2014-04-01',
# ...

# %%
df[df["id"] == "17530971"]
# Out:
# Empty DataFrame
# Columns: [created, modified, id, conceptrecid, doi, conceptdoi, doi_url, metadata, title, links, updated, recid, revision, files, swh, owners, status, stats, state, submitted]
# Index: []

# %%
df_files[df_files["key"] == "1.pdf"]
# Out:
#          created                modified        id  conceptrecid  \
# 0  1762334680954 2026-02-16 08:14:00.800  17530971      17530970
#
#                        doi               conceptdoi  \
# 0  10.5281/zenodo.17530971  10.5281/zenodo.17530970
#
#                                    doi_url  \
# 0  https://doi.org/10.5281/zenodo.17530971
#
#                                             metadata  \
# 0  {'title': 'L'état de l'Enseignement supérieur ...
#
#                                                title  \
# 0  L'état de l'Enseignement supérieur et de la Re...
#
#                                                links  ...  \
# 0  {'self': 'https://zenodo.org/api/records/17530...  ...
#
#                 owners     status  \
# 0  [{'id': '1451665'}]  published
#
#                                                stats  state submitted  \
# 0  {'downloads': 40, 'unique_downloads': 11, 'vie...   done      True
#
#                                      id    key      size  \
# ...

# %%
df_dup = df_files[df_files.duplicated(subset="key")]
df_dup[["modified", "id", "doi", "key", "checksum", "links.self"]]
# Out:
#                     modified        id                                    id  \
# 635  2026-02-16 13:14:03.909  18660447  acde2b8e-44c4-4f96-b8fb-d8d0d76b83fa
# 636  2026-02-16 13:14:07.087  18660449  c7716cf2-866d-49d4-9ee3-224b41510ab9
# 637  2026-02-16 13:14:10.575  18660451  e5f23458-d3ce-417a-a182-4a7234bd8024
# 638  2026-02-16 13:14:14.617  18660455  e0c72284-f345-44d5-9195-e3b967406f28
# 939  2026-02-16 16:44:24.467  18662899  a1561402-b919-4b1f-a7d8-d7242d453b2a
# 940  2026-02-16 16:44:27.586  18662901  29fe0bff-0e81-4f91-9b02-faa21dd71b74
# 941  2026-02-16 16:44:30.954  18662903  4627018c-fb1d-4b7f-82bb-3b8d3d882592
# 942  2026-02-16 16:44:34.118  18662905  bcc3100a-d5f1-4d8b-8a31-989138c3683e
# 943  2026-02-16 16:44:38.721  18662907  68cdafc7-d20a-4a7d-bf6d-b8411c4ee25e
# 944  2026-02-16 16:44:41.373  18662909  c029e7e2-c30b-4f79-9a70-6234ceac013d
# 945  2026-02-16 16:44:44.135  18662911  240cdc43-bf87-4fec-acb8-42bacd3d2c9b
# ...

# %%
df_files[df_files["key"] == "1003.pdf"][["doi", "doi_url", "title", "links.self", "modified"]].to_dict(orient="records")
# Out:
# [{'doi': '10.5281/zenodo.18660443',
#   'doi_url': 'https://doi.org/10.5281/zenodo.18660443',
#   'title': 'Les boursiers sur critères sociaux en 2020-2021',
#   'links.self': 'https://zenodo.org/api/records/18660443/files/1003.pdf/content',
#   'modified': Timestamp('2026-02-16 13:14:00.075000')},
#  {'doi': '10.5281/zenodo.18660447',
#   'doi_url': 'https://doi.org/10.5281/zenodo.18660447',
#   'title': 'Les boursiers sur critères sociaux en 2020-2021',
#   'links.self': 'https://zenodo.org/api/records/18660447/files/1003.pdf/content',
#   'modified': Timestamp('2026-02-16 13:14:03.909000')},
#  {'doi': '10.5281/zenodo.18660449',
#   'doi_url': 'https://doi.org/10.5281/zenodo.18660449',
#   'title': 'Les boursiers sur critères sociaux en 2020-2021',
#   'links.self': 'https://zenodo.org/api/records/18660449/files/1003.pdf/content',
#   'modified': Timestamp('2026-02-16 13:14:07.087000')},
#  {'doi': '10.5281/zenodo.18660451',
# ...

# %% [markdown]
# pdf extraction

# %%
import os
from mistralai.client import Mistral
from dotenv import load_dotenv

load_dotenv()

client = Mistral(api_key=os.getenv("MISTRAL_API_KEY"))

# %%
import base64


def encode_pdf(pdf_path):
    try:
        with open(pdf_path, "rb") as pdf_file:
            return base64.b64encode(pdf_file.read()).decode("utf-8")
    except Exception as error:
        print(f"Error: {error}")
        return None

# %%
import json

pdf_path = "./data/pdf/1003.pdf"
base64_pdf = encode_pdf(pdf_path)

response = client.ocr.process(
    model="mistral-ocr-latest",
    document={
        "type": "document_url",
        "document_url": f"data:application/pdf;base64,{base64_pdf}",
        "document_name": "1003.pdf",
    },
    extract_footer=True,
    extract_header=True,
)
data = json.loads(response.model_dump_json())

# %%
response.model_dump_json()
# Out:
# '{"pages":[{"index":0,"markdown":"# Les boursiers sur critères sociaux en 2020-2021\\n\\nDurant l\'année universitaire 2020-2021, marquée par la crise sanitaire, 750 000 étudiants ont perçu une bourse sur critères sociaux (BCS) du M.E.S.R.I., soit une hausse de plus de 4 % en 1 an. Cette hausse atteint 7 % pour les étudiants ayant les plus faibles ressources. La proportion de boursiers au sein des formations ouvrant droit aux bourses dépasse 38 %, taux en hausse annuelle de 1,6 point après 4 années de baisse. De nouvelles aides à destination des boursiers ont été créées au cours de l\'année pour faire face au prolongement de la crise. Entre septembre 2020 et juin 2021, plus de 315 000 étudiants boursiers ont bénéficié de l\'une d\'elles : le ticket repas à 1 euro. Cette aide a été pérennisée comme un droit connexe aux BCS en juillet 2021.\\n\\n## En 2020-2021, 750 000 étudiants boursiers\\n\\nDurant l\'année universitaire 2020-2021, 750 000 étudiants ont perçu une bourse sur critères
# ...

# %%
data.keys()
# Out:
# dict_keys(['pages', 'model', 'usage_info', 'document_annotation'])

# %%
data.get("model")
# Out:
# 'mistral-ocr-latest'

# %%
data.get("pages")[1]
# Out:
# {'index': 1,
# ...

# %%
print(
    "MINISTÈRE\nDE L'ENSEIGNEMENT\nSUPÉRIEUR,\nDE LA RECHERCHE\nET DE L'INNOVATION\n\nLiberté\nÉgalité\nFraternité\n\nNOTE FLASH DU\nSIES\nEnseignement supérieur, Recherche, Innovation\nN° 20\nSeptembre 2021\n\n# Les boursiers sur critères sociaux en 2020-2021\n\nDurant l'année universitaire 2020-2021, marquée par la crise sanitaire, 750 000 étudiants ont perçu une bourse sur critères sociaux (BCS) du M.E.S.R.I., soit une hausse de plus de 4 % en 1 an. Cette hausse atteint 7 % pour les étudiants ayant les plus faibles ressources. La proportion de boursiers au sein des formations ouvrant droit aux bourses dépasse 38 %, taux en hausse annuelle de 1,6 point après 4 années de baisse. De nouvelles aides à destination des boursiers ont été créées au cours de l'année pour faire face au prolongement de la crise. Entre septembre 2020 et juin 2021, plus de 315 000 étudiants boursiers ont bénéficié de l'une d'elles : le ticket repas à 1 euro. Cette aide a été pérennisée comme un droit connexe aux BCS en juillet 2021.\n\n## En 2020-2021, 750 000 étudiants boursiers\n\nDurant l'année universitaire 2020-2021, 750 000 étudiants ont perçu une bourse sur critères sociaux (BCS) du ministère de l'enseignement supérieur, de la recherche et de l'innovation¹ (M.E.S.R.I.). Ces bourses ne peuvent être attribuées qu'aux étudiants inscrits dans une formation habilitée par le ministère en charge de l'enseignement supérieur à recevoir des boursiers, avec des conditions sur l'âge, le régime d'inscription, la nationalité et le diplôme.\n\nElles sont accordées en fonction des ressources et des charges de la famille appréciées selon un barème national qui détermine le montant annuel de la bourse. L'échelon 7, échelon pour les ressources les plus faibles, correspond à une bourse de 5 679 € annuels et concerne 7,5 % des boursiers. Près d'un tiers des boursiers ont une bourse supérieure à 4 610 €, ce montant est supérieur à 2 571 € pour plus de la moitié des boursiers. Enfin, 32 % des boursiers sont à l'échelon 0 et bénéficient d'une aide de 1 032 €.\n\n### Effectifs de boursiers sur critères sociaux\n\n|   | Montant annuel en euros * | Effectifs | % | % de femmes  |\n| --- | --- | --- | --- | --- |\n|  Echelon 0 | 1 032 | 238 162 | 31,8 | 56,8  |\n|  Echelon 1 | 1 707 | 105 137 | 14,0 | 57,6  |\n|  Echelon 2 | 2 571 | 55 004 | 7,3 | 58,1  |\n|  Echelon 3 | 3 292 | 55 578 | 7,4 | 58,8  |\n|  Echelon 4 | 4 015 | 53 554 | 7,1 | 58,7  |\n|  Echelon 5 | 4 610 | 97 850 | 13,1 | 59,3  |\n|  Echelon 6 | 4 889 | 88 185 | 11,8 | 59,8  |\n|  Echelon 7 | 5 679 | 56 092 | 7,5 | 61,0  |\n|  Total |  | 749 562 | 100 | 58,3  |\n|  Aide au mérite | 900 | 45 353 | 6,1 | 64,1  |\n\n* Les montants des BCS ne prennent pas en compte le supplément de 150 euros versé aux boursiers en décembre 2020 en raison de la crise sanitaire.\nSource : MESRI-SIES / Système d'information AGLAE, extraction 15/03/2021\n\nPour les bacheliers bénéficiant d'une BCS et ayant eu une mention « Très bien », une aide au mérite vient compléter la BCS durant trois ans. En 2020, cette aide était de 900 €.\n\n## 38,4 % de boursiers, en hausse de 1,6 point\n\nLe nombre de boursiers a augmenté de plus de 4,4 % en un an, une hausse deux fois plus importante que celle des inscriptions à la rentrée 2020². Cette augmentation atteint 6,9 % au sein des échelons 5, 6 et 7 qui concernent les étudiants ayant les ressources les plus faibles. La part des étudiants boursiers dans les formations ouvrant droit à une bourse du M.E.S.R.I. est de 38,4 % en 2020-2021. En baisse depuis 4 ans, ce taux augmente fortement cette année (+1,6 point), dépassant la part de boursiers observée à la rentrée 2015 (37,9 %).\n\nDes disparités par académie et par genre persistent. La part de boursiers est très élevée en Outre-mer (de 46 à 63 %). Par contraste, environ un tiers des étudiants des académies de Strasbourg et Lyon sont boursiers, et seulement d'un peu plus d'un quart dans les académies de Paris et Versailles. La part de boursiers dans une académie dépend non seulement du niveau de vie des familles mais aussi de l'offre de formation.\n\nParmi l'ensemble des étudiantes, quatre sur dix sont boursières. C'est le cas d'un étudiant sur trois. Cet écart s'explique par une plus forte propension des femmes à poursuivre des études dans les milieux les plus modestes. Elles sont d'ailleurs plus nombreuses parmi les échelons les plus élevés où elles représentent 60 % des boursiers contre 57 % à l'échelon 0. Des disparités se retrouvent aussi selon les formations : on observe davantage de boursières que de boursiers en STS (+5 points) et en IUT (+4 points) ; l'écart est moindre en CPGE, dans les écoles d'ingénieur ou de commerce qui accueillent moins d'étudiants boursiers.\n\nNote Flash n°20 – septembre 2021\n\n1 Les étudiants peuvent bénéficier d'autres aides, non prises en compte ici : aides spécifiques ponctuelles du MESRI, bourses d'établissement et des autres ministères. Les aides spécifiques ponctuelles (ASP), ouvertes aux étudiants boursiers ou non, varient fortement selon la conjoncture. En lien avec la crise sanitaire, de septembre 2020 à avril 2021, le nombre de bénéficiaires par mois était, en moyenne, de 43 % plus élevé que l'année précédente. Le montant des aides allouées a progressé de 57 % sur la même période.\n2 Entre les rentrées 2019 et 2020, le nombre des inscriptions dans l'ensemble de l'enseignement supérieur a progressé de 2,1 % (formations non éligibles aux BCS du MESRI comprises)"
)
# Out:
# MINISTÈRE
# DE L'ENSEIGNEMENT
# SUPÉRIEUR,
# DE LA RECHERCHE
# ET DE L'INNOVATION
#
# Liberté
# Égalité
# Fraternité
#
# NOTE FLASH DU
# SIES
# Enseignement supérieur, Recherche, Innovation
# N° 20
# Septembre 2021
#
# # Les boursiers sur critères sociaux en 2020-2021
#
# ...

# %%
import re
from dataclasses import dataclass, field


def table_to_dict(raw: str):
    lines = [line.strip() for line in raw.strip().splitlines()]
    # Remove separator line
    lines = [line for line in lines if not re.match(r"^\|[-:\s|]+\|$", line)]

    rows = []
    for line in lines:
        cells = [cell.strip() for cell in line.strip("|").split("|")]
        rows.append(cells)

    if not rows:
        return None

    headers = rows[0]
    data = rows[1:]

    return {"headers": headers, "data": data}


@dataclass
class Section:
    level: int  # 1=title, 2=h2, 3=h3
    title: str
    paragraphs: list[str] = field(default_factory=list)
    tables: list[str] = field(default_factory=list)  # raw markdown table strings


def parse_markdown(md: str) -> list[Section]:
    sections: list[Section] = []
    current: Section | None = None
    buffer: list[str] = []

    def flush_buffer():
        if current is None or not buffer:
            return
        block = "\n".join(buffer).strip()
        if not block:
            return

        # Split block into chunks separated by blank lines
        for chunk in re.split(r"\n{2,}", block):
            chunk = chunk.strip()
            if not chunk:
                continue

            lines = chunk.splitlines()
            # A table has at least one | and a separator line with ---
            is_table = any("|" in line for line in lines) and any(re.match(r"^\s*\|[\s\-|:]+\|\s*$", line) for line in lines)

            if is_table:
                current.tables.append(table_to_dict(chunk))
            else:
                if chunk:
                    current.paragraphs.append(chunk)
        buffer.clear()

    for line in md.splitlines():
        heading = re.match(r"^(#{1,3})\s+(.*)", line)
        if heading:
            flush_buffer()
            level = len(heading.group(1))
            title = heading.group(2).strip()
            current = Section(level=level, title=title)
            sections.append(current)
        else:
            if current is not None:
                buffer.append(line)

    flush_buffer()
    return sections

# %%
md = data.get("pages")[0].get("markdown")
sections = parse_markdown(md)

# %%
sections[2].tables
# Out:
# [{'headers': ['',
#    'Montant annuel en euros *',
#    'Effectifs',
#    '%',
#    '% de femmes'],
#   'data': [['Echelon 0', '1 032', '238 162', '31,8', '56,8'],
#    ['Echelon 1', '1 707', '105 137', '14,0', '57,6'],
#    ['Echelon 2', '2 571', '55 004', '7,3', '58,1'],
#    ['Echelon 3', '3 292', '55 578', '7,4', '58,8'],
#    ['Echelon 4', '4 015', '53 554', '7,1', '58,7'],
#    ['Echelon 5', '4 610', '97 850', '13,1', '59,3'],
#    ['Echelon 6', '4 889', '88 185', '11,8', '59,8'],
#    ['Echelon 7', '5 679', '56 092', '7,5', '61,0'],
#    ['Total', '', '749 562', '100', '58,3'],
#    ['Aide au mérite', '900', '45 353', '6,1', '64,1']]}]

# %% [markdown]
# # EESR

# %%
import pandas as pd

eesr_df = pd.read_json("../data/eesr_pages.jsonl", lines=True)

# %%
eesr_df[["PAGE_COURANTE_ID", "PAGE_TITRE_FR", "PAGE_NOM_DE_CODE", "PAGE_TEXTE_FR"]]
# Out:
#     PAGE_COURANTE_ID                                      PAGE_TITRE_FR  \
# 0                 60  les étudiants inscrits dans l'enseignement sup...
# 1                 61                                   la R&D en France
# 2                 62          MIRES - Programmes LOLF pour la recherche
# 3                 63  Crédits budgétaires RECHERCHE de la MIRES : ré...
# 4                 64  les objectifs socio-économiques retenus pour l...
# ..               ...                                                ...
# 74                56  Publications scientifiques et brevets dans le ...
# 75                57      les activités de R&D dans les biotechnologies
# 76                58                      la recherche en environnement
# 77                59                les activités de R&D en agriculture
# 78                60                les activités de R&D en agriculture
#
#    PAGE_NOM_DE_CODE                                      PAGE_TEXTE_FR
# ...

# %%
eesr_df[eesr_df["PAGE_ID"] == 2353]["PUBLICATION"].to_dict()
# Out:
# {37: {'PUBLICATION_ID': '1234',
#   'PUBLICATION_ID_FR': '1167',
#   'PUBLICATION_EDITEUR_ID': '21',
#   'PUBLICATION_COLLECTION_ID': '40',
#   'PUBLICATION_NOM_DE_CODE': 'EESR19',
#   'PUBLICATION_TITRE_FR': "état de l'Enseignement supérieur, de la Recherche et de l'Innovation en France",
#   'PUBLICATION_TITRE_COMPLET_FR': "état de l'Enseignement supérieur, de la Recherche et de l'Innovation en France n°19",
#   'PUBLICATION_SOUS_TITRE_FR': 'XX indicateurs',
#   'PUBLICATION_TITRE_EN': 'Higher education, research & innovation in France, facts and figures',
#   'PUBLICATION_TITRE_COMPLET_EN': 'Higher education, research & innovation in France, facts and figures 19th edition',
#   'PUBLICATION_SOUS_TITRE_EN': 'xx indicators',
#   'PUBLICATION_DATE_ANNEE': '2026',
#   'PUBLICATION_DATE_COUV': 'Juin 2026',
#   'PUBLICATION_DATE_MISE_EN_LIGNE': 'Juin 2026',
#   'PUBLICATION_DATE_TRI': '2026-06',
#   'PUBLICATION_NUMERO': '19',
# ...
